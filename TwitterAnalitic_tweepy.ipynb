# %%
# Librerias

install = False
if install:
    # !pip install pandas
    # !pip install tweepy
    

    # Python Script to Extract tweets of a 
# particular Hashtag using Tweepy and Pandas
  
  
# import modules
import pandas as pd
import tweepy
  
  
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    print(f"Hashtags Used:{ith_tweet[9]}")
  
  
# function to perform data extraction
def scrape(words, date_since, numtweet):
      
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags', 'created_at'])
      
    tweets = tweepy.Cursor(api.search, q=words, lang="es",
                           since=date_since, tweet_mode='extended').items(numtweet)
     
    list_tweets = [tweet for tweet in tweets]
      
    i = 1  
      
    for tweet in list_tweets:
        print(tweet)
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
        created_at = tweet.created_at
          
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext, created_at]
        db.loc[len(db)] = ith_tweet
          
        i = i+1
    filename = 'scraped_tweets.csv'
      
    # we will save our database as a CSV file.
    db.to_csv(filename)

# %%
twitter_params = {
    'consumer_key': 'consumer_key',
    'consumer_secret': 'consumer_secret',
    'access_token_key': 'access_token_key',
    'access_token_secret': 'access_token_secret',
}

auth = tweepy.OAuthHandler(twitter_params['consumer_key'], twitter_params['consumer_secret'])
auth.set_access_token(twitter_params['access_token_key'], twitter_params['access_token_secret'])
api = tweepy.API(auth)

auth = tweepy.OAuthHandler(twitter_params['consumer_key'], twitter_params['consumer_secret'])
auth.set_access_token(twitter_params['access_token_key'], twitter_params['access_token_secret'])
api = tweepy.API(auth)

# words = '#NoMásPobresEnUnPaísRico #KeikoPresidenta'
words = '#DebatePresidencial'

date_since = '2021-05-30'
numtweet = 1000


scrape(words, date_since, numtweet)
print('Scraping completado!')
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-84-04996846b79d> in <module>
#      21
#      22
# ---> 23 scrape(words, date_since, numtweet)
#      24 print('Scraping completado!')
#
# <ipython-input-81-7b3117012c61> in scrape(words, date_since, numtweet)
#      41                            since=date_since, tweet_mode='extended').items(numtweet)
#      42
# ---> 43     list_tweets = [tweet for tweet in tweets]
#      44
#      45     i = 1
#
# <ipython-input-81-7b3117012c61> in <listcomp>(.0)
#      41                            since=date_since, tweet_mode='extended').items(numtweet)
#      42
# ---> 43     list_tweets = [tweet for tweet in tweets]
#      44
#      45     i = 1
#
# /backup/.personal/UNI/2021-I/ANALITICA DE DATOS/notebook/.venv/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ...

# %%
df = pd.read_csv('scraped_tweets.csv',sep=',')

# %%
df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, username, description, location, following, followers, totaltweets, retweetcount, text, hashtags]
# Index: []

# %%
df = pd.read_csv('scraped_tweets-castillo.csv',sep=',')
df
# Out:
#     Unnamed: 0         username  \
# 0            0      ballon_hugo
# 1            1         Pen_Bird
# 2            2       M_Jordache
# 3            3   bernie20twenty
# 4            4          kcnwms1
# 5            5      _ocho_patas
# 6            6      shantanav_c
# 7            7    satanasandino
# 8            8          edkamil
# 9            9        themainfa
# 10          10  PedroHumbertoS9
# 11          11    SalomeChavez_
# 12          12       apululu_19
# 13          13       Ulisse0672
# 14          14    Abzcommunists
# 15          15      JenyTorresg
# 16          16      sam28459977
# 17          17          kcnwms1
# 18          18       CesFabian5
# 19          19      JorgeNizama
# 20          20        poeboston
# 21          21        poeboston
# 22          22        poeboston
# 23          23   Carlos05105988
# 24          24       OutofSystm
# 25          25   doctorclownery
# 26          26           MSDLCE
# 27          27   Renato_E_Gozzi
# ...

# %%
df = pd.read_csv('scraped_tweets-keiko.csv',sep=',')
df
# Out:
#      Unnamed: 0         username  \
# 0             0    _camilaastete
# 1             1     Maez93155622
# 2             2  Francis58631798
# 3             3       stephgard2
# 4             4  zenayda47080748
# ..          ...              ...
# 102         102  Incisiva_yuliet
# 103         103     ScottDorian4
# 104         104  MikelVizzualbzK
# 105         105           JRiccr
# 106         106     ScottDorian4
#
#                                            description  \
# 0                                                   🦋❣
# 1                                              Not now
# 2                                                  NaN
# 3    Amo a los animales (mi razón por ser vegetaria...
# 4                                                 Aley
# ..                                                 ...
# 102  Somos un Estado de derecho donde opinamos part...
# 103  Peruano graduado en Administration BM #PennSta...
# 104  #MH370 ← Malaysia Airlines  #PrayForSouthKorea...
# ...
